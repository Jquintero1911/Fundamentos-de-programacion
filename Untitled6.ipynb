# %%
"""
Programa: ingenieria de sistemas
Autor: Cristian Rudas Velez
Versión: 1.0
"""

# %%
#EJERCICIO 1
num = 0
ult = 0
def FUN_ultimodigito(num):
 num = int(input("Ingrese un número: "))
 ult = num%10
 print("Su último digito es: ", ult)

FUN_ultimodigito(num)

# %%
#EJERCICIO 2
num = 0
ult = 0
def FUN_ultimodigito(num):
 num = int(input("Ingrese un número: "))
 ult = num%100
 print("Sus dos últimos digitos son: ", ult)

FUN_ultimodigito(num)
