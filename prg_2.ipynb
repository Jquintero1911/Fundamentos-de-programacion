# %% [markdown]
# # **Ejercicio 1:**
#
# ---
#
# Dos pueblos que distan 12km estan a unidos por una carretera recta. Un ciclista viaja de un pueblo al otro con una velocidad constante de 10m/s calcula el tiempo que emplea.
#
# Nombre del programa: prg_2.
#
# Ejercicio 1
#
#
# Autor:
# Jeronimo Quintero

# %%
#declaracion de variables 
DistanciaEntrePueblos = 0 #variable donde se captura

# %%
#Obtencion de datos
DistanciaEntrePueblos = int(input("¿Cual es la distancia entre pueblos?: "));
VelocidadCiclista = int(input("¿cual es la velocidad del ciclista en m/s: "));
