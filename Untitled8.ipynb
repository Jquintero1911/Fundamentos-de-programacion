# %%
class coche():
#atributos
  ruedas = 4
  cilindraje= 1000
  combustible="gasolina"
  puerta = 3

#metodo
  def desplazamiento(self):
    print("el coche se esta desplazando sobre 4 ruedas")

# Programa principal

#generar instancia de la clase 
#instanciar un objeto
#declarar un objeto

miVehiculo=coche()
obj_miCarrito=coche()

#accesar al atributo
print("mi coche tiene ",miVehiculo.ruedas, "ruedas")
print("mi coche tiene ",miVehiculo.cilindraje, "de cilindraje")
print("mi coche tiene ",miVehiculo.combustible, "de combustible")
print("mi coche tiene ",miVehiculo.puerta, "puertas")

miVehiculo.desplazamiento()
obj_miCarrito.desplazamiento()
# Out:
# mi coche tiene  4 ruedas
# mi coche tiene  1000 de cilindraje
# mi coche tiene  gasolina de combustible
# mi coche tiene  3 puertas
# el coche se esta desplazando sobre 4 ruedas

# %%
class coche():
  ruedas= 4
  def desplazamiento(self):
    print("El coche se desplaza sobre 4 ruedas")
class moto():
  ruedas= 2
  def desplazamiento(self):
    print("La moto se desplaza sobre 2 ruedas")
miCarro=coche()
print("El coche tiene", miCarro.ruedas, "ruedas")
miCarro.desplazamiento()
print("----------Segundo objeto--------")
mimoto=moto()
print("Mi moto tiene", mimoto.desplazamiento, "ruedas")
mimoto.desplazamiento()
# Out:
# El coche tiene 4 ruedas
# El coche se desplaza sobre 4 ruedas
# ----------Segundo objeto--------
# Mi moto tiene <bound method moto.desplazamiento of <__main__.moto object at 0x7fb5b6819ad0>> ruedas
# La moto se desplaza sobre 2 ruedas

# %%
#constructor
class cachorro():
  # Metodo constructor
   def __init__(self,p_color,p_raza):
     self.color=p_color
     self.raza=p_raza




perrito = cachorro("marron claro" , "golden retriever")
obj_perritoVicky= cachorro("blanco ", "shitzu" )
obj_perritoElbryan = cachorro ("Negro", "sin identificar")



print("este es un cachorro de la raza {} y es de color {}".format(perrito.raza, perrito.color))
print("este es el perrito de vicky y la raza {} y es de color {}".format(obj_perritoVicky.raza, obj_perritoVicky.color))
print("este es el perro del bryan y la raza {} y es de color {}".format(obj_perritoElbryan.raza, obj_perritoElbryan.color))
# Out:
# este es un cachorro de la raza golden retriever y es de color marron claro
# este es el perrito de vicky y la raza shitzu y es de color blanco
# este es el perro del bryan y la raza sin identificar y es de color Negro

# %%
class cachorro():
  # metodo constructor
  def __init__(self, P_color, P_raza, P_nombre):
    self.color = P_color
    self.raza = P_raza
    self.nombre = P_nombre

#modulo principal
P_color = input("color: ")
P_raza = input("raza: ")
P_nombre = input("nombre: ")

perrito=cachorro(P_color, P_raza, P_nombre)
print("este es un cachorro sin dueño y la raza {} y es de color {} y se llama {}".format(perrito.raza,perrito.color,perrito.nombre))

# %%
class C_rectangulo:
  def __init__(self,P_ancho,P_alto):
    self.at_ancho = P_ancho
    self.at_alto = P_alto
  
  def m_area(self):
    area = self.at_alto*self.at_ancho
    return area
  
  def m_perimetro(self):
    perimetro = (self.at_alto*2)+(self.at_ancho*2)
    return perimetro

r1 = C_rectangulo(4,2)
area = r1.m_area()
perimetro = r1.m_perimetro()
print("El area es: ", area)
print("El perimetro es: ", perimetro)

P_ancho = int(input("Ingrese el ancho del rectangulo: "))
P_alto = int(input("Ingrese el alto del rectangulo"))

obj_rect2 = C_rectangulo(P_ancho, P_alto)

print("El area del rectangulo es: ",str(obj_rect2.m_area()))
print("El perimetro del rectangulo es: ",str(obj_rect2.m_perimetro()))
# Out:
# El area es:  8
# El perimetro es:  12
# Ingrese el ancho del rectangulo: 12
# Ingrese el alto del rectangulo12
# El area del rectangulo es:  144
# El perimetro del rectangulo es:  48
