# %%
#Ejercicio 10
#Recibe parametro y no retorna un valor
def PrimerDig(Num):
  while (Num>=10):
   Num=int(Num/10)
  print("El primer digito es: ",Num)
Num=int(input("Ingrese un numero: "))
#Llamado de la función
PrimerDig(Num)

# %%
#Ejercicio 10
#Recibe parametro y retorna un valor
def PrimerDig(Num):
  Num=int(input("Ingrese un número: "))
  while (Num>=10):
   Num=int(Num/10)
  return(Num)
#Llamado de la función
print("El primer digito es: ",PrimerDig(Num))

# %%
#Ejercicio 10
#No recibe parametro y retorna un valor
def PrimerDig():
  Num=int(input("Ingrese un número: "))
  while (Num>=10):
   Num=int(Num/10)
  return(Num)
#Llamado de la función
print("El primer digito es: ", PrimerDig())

# %%
#Ejercicio 10
#No recibe parametro y no retorna un valor
def PrimerDig():
  Num=int(input("Ingrese un número: "))
  while (Num>=10):
   Num=int(Num/10)
  print("El primer digito es: ",Num)
#Llamado de la función
PrimerDig()
