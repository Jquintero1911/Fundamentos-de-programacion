# %%
  import pandas as pd
notaSemillero = pd.DataFrame({"Nombres":["Pedro","Darden","Leidy","Luis","Martha","Andrea","Carlos","Felipe","Andres","Julian"],
                             "Semestre":[10,9,7,8,10,9,10,8,9,8]})
notaSemillero["Nota 1"] = 3
notaSemillero
notaSemillero["Nota 2"] = [3,4,2,1,4,7,4,2,4,7]
notaSemillero
notaSemillero.insert(4,"Ciudad",["Manizales","Cali","Pereira","Manizales","Chinchina","Cali","Manizales","Manizales","Chinchina","Manizales"])
notaSemillero=notaSemillero.assign(Departamento=["Caldas","Valle","Risaralda","Caldas","Caldas","Valle","Caldas","Caldas","Caldas","Caldas"])
notaSemillero.loc[3]=["Lucia",7,4.5,3.5,"Armenia","Quindio"]
notaSemillero.loc[10]=["Carolina",7,4.5,3.5,"Armenia","Quindio"]
notaSemillero.loc[11]=["Maria",7,4.5,3.5,"Armenia","Quindio"]
notaSemillero=notaSemillero.append({"Nombres" : "Laurita", "Semestre":9,"Nota 1":3.8,"Nota 2":4, "Ciudad":"Cali","Departamento":"Valle"},ignore_index=True)
notaSemillero.iloc[5,4]=input("Ingrese el lugar: ")
notaSemillero.iloc[5,5]=input("Ingrese el lugar: ")
print(notaSemillero)

# %%
Df1=(notaSemillero)[["Nota 1","Nota 2"]]
print(Df1)
# Out:
#     Nota 1  Nota 2
# 0      3.0     3.0
# 1      3.0     4.0
# 2      3.0     2.0
# 3      4.5     3.5
# 4      3.0     4.0
# 5      3.0     7.0
# 6      3.0     4.0
# 7      3.0     2.0
# 8      3.0     4.0
# 9      3.0     7.0
# 10     4.5     3.5
# 11     4.5     3.5
# 12     3.8     4.0
