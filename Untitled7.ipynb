# %%
Nombre = ''
apellido= ''
nombreCompleto= ''

Nombre= input("Digite su nombre: ")
apellido = input("Digite su apellido: ")

nombreCompleto = Nombre+ " " +apellido
print("Su nombre completo es: " , nombreCompleto)

# %%
mensaje9 = "hola mundo "
print(mensaje9[:9].find("d"))
