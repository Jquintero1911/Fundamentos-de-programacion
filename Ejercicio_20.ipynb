# %%
"""
Autores: Juan José Martinez, Jeronimo Quintero, Cristian Rudas
Programa: Ingenieria de sistemas y telecomunicaciones
Versión: 1.0
Fecha: 26/10/2022
"""

# %%
#Recibe parametros y no retorna valor
def NumerosIguales(Num):
 Aux=Num
 Contador_1=0
 while (Aux>0):
   Contador_1=Contador_1+1
   Aux=Aux/10
 Dig=Num%10
 Contador_2=0
 while (Num>0):
   if (Num%10==Dig):
     Contador_2=Contador_2+1
   Num=Num/10
 if Contador_1==Contador_2:
   return(1)
 else:
   return(0)
Num=int(input("Ingrese un número: "))
#Llamado de la función
NumerosIguales(Num)
