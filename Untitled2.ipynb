# %%
Total_correc = 0 
Total_incorrec = 0
Total_en_blan = 0
Valor_Final = 0
Res_Correc = int(input("ingrese la cantidad de respuestas correctas "))
Res_Incorre = int(input("ingrese la cantidad de respuestas incorrectas "))
Res_En_blan = int(input("ingrese la cantidad de respuestas en blanco "))
Total_correc = (Res_Correc*4)
Total_Incorre = (Res_Incorre*-1)
Total_en_blan = (Res_En_blan*0)
Valor_Final = (Total_correc+Total_incorrec)
print("su puntaje final es de ",Valor_Final)
# Out:
# ingrese la cantidad de respuestas correctas 4
# ingrese la cantidad de respuestas incorrectas 2
# ingrese la cantidad de respuestas en blanco 1
# su puntaje final es de  16
