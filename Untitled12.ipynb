# %%
def digitosiguales(Int:num):
 #inicio
 int(contador1,contador2,dig,aux)
Aux =Numcontador1=0
while aux > 0: 
   Contador1=contador1+1
   aux=aux/10

dig = num MOD10
contador2=0 
while num > 0:
if num mod10 = dig 
 contador2= contador2+1
 finsi
num=num/10
finmientras
if contador1=contador2
return(1)
else
return(0)
