# %%
#Ejercicio numero 1
inicio = 0
fin = 0 
inicio = int(input("ingrese el numero de inicio: "))
fin = int(input("ingrese el numero del fin: "))
for x in range(inicio,fin,):
  print(x)

# %%
a = int(input("ingrese valor de (N): "))
b = 0
for i in range(1,a+1):
   print(i)
   b = b+i
   print("la suma es: ", b)

# %%
n = int(input("ingrese el valor de n "))
a = 0 
b = 1
while i <= 1

# %%
def ciclo(n):
    a=1
    b=1
    if n==1:
        print('0')
    elif n==2:
        print('0','1')
    else:
        print('0')
        print(a)
        print(b)
        for i in range(n-3):
            total = a + b
            b=a
            a= total
            print(total)
ciclo(9)
