# %%
# declaracion e inicializacion de variables 
var_int_numeroUno = 0
var_int_NumeroDos = 0

# %%
# lectura entrada por teclado 
#para las lecturas de datos numericos se deben convertir a su tipo 
var_int_numeroUno = input("dijite numero uno  ")
var_int_NumeroDos = input("dijite numero dos  ")
# Out:
# dijite numero uno  50
# dijite numero dos  60

# %%
# procesos

# %%
# salidas- impresiones de resultados 
print("El numero uno es: ", var_int_numeroUno);
print("el numero dos es: ", var_int_NumeroDos);
# Out:
# El numero uno es:  50
# el numero dos es:  60
